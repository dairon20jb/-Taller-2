# %% [markdown]
# <a href="https://colab.research.google.com/github/dairon20jb/-Taller-2/blob/master/Taller_en_clase_Intro_a_la_probabilidad_para_ML_Dairon_Barbosa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller en clase #1
#
# Febrero 10 del 2021
#
# Dairon Javier Barbosa Barbosa
#
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=1000
m=50
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.308 var_est= 0.21313599999999996

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n,p = 10, 0.5
from scipy.stats import binom
mean, var = binom.stats(n, p, moments='mv')
r = binom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Binomial con p= "+str(p))
plt.show()

# %%
#Ordenar de menor a mayor
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Binomial Ordenada con p="+str(p))
plt.show()

# %%
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p))
plt.show()
#Tipo de arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 5.038 var_est= 2.2525560000000002
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.007600000000000051 % de la media 0.09897759999999992 % de la varianza

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3
from scipy.stats import geom
mean, var = geom.stats(p, moments='mv')
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Geométrica con p= "+str(p))
plt.show()

# %%
#Ordenar de menor a mayor
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Geométrica Ordenada con p="+str(p))
plt.show()

# %%
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Gemoétrica con p="+str(p))
plt.show()
#Tipo de arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la geométrica con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la geométrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la geométrica con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la geométrica con p= 0.3 son u_est= 3.311 var_est= 6.870279
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.006700000000000061 % de la media 0.11667841428571438 % de la varianza

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson
mean, var = poisson.stats(L, moments='mv')
r = poisson.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Poisson con L= "+str(L))
plt.show()
#Ordenar de menor a mayor
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Poisson Ordenada con L="+str(L))
plt.show()
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Poisson con L="+str(L))
plt.show()
#Tipo de arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Poisson con L=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Poisson con L=",L,"son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Poisson con L= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para la Poisson con L= 5 son u_est= 5.034 var_est= 4.558843999999999
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.0067999999999999615 % de la media 0.08823120000000025 % de la varianza

# %%
#Binomial negativa con parametro p después de r fallos
r,p = 5,0.5
from scipy.stats import nbinom
mean, var = nbinom.stats(r, p, moments='mv')
R = nbinom.rvs(r, p, size=N)
plt.plot(R)
plt.title(str(N)+" puntos distribuidos Binomial Negativa con p= "+str(p))
plt.show()
#Ordenar de menor a mayor
R.sort()
plt.plot(R)
plt.title(str(N)+" puntos distribuidos Binomial Negativa Ordenada con p="+str(p))
plt.show()
#Histograma
plt.hist(R, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Binomial Negativa con p="+str(p))
plt.show()
#Tipo de arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo R:")
print(type(R))
print("Vamos a hallar algunas estimaciones de estadisticas de R")
avg=R.mean()
varest=R.var()
print("Los valores teoricos de la media y varianza para la Binomial Negativa con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Binomial Negativa con p=",p,"son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo R:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de R
# Los valores teoricos de la media y varianza para la Binomial Negativa con p= 0.5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la Binomial Negativa con p= 0.5 son u_est= 4.904 var_est= 9.508784
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.019200000000000016 % de la media 0.04912159999999997 % de la varianza

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=100000
m=50
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
from scipy.stats import norm
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
#Ordenado
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
#Tipo de Arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.998901381233632 var_est= 0.2466774046428929
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.00021972375327354853 % de la media 0.013290381428428422 % de la varianza

# %%
# Uniforme entre 0 y 255
b= 255
from scipy.stats import uniform
mean, var = scipy.stats.uniform.stats(moments='mv',loc=0,scale=b)
r = scipy.stats.uniform.rvs (loc=0,scale=b, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Uniforme entre 0 y "+str(b))
plt.show()
#Ordenado
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Uniforme ordenados entre 0 y "+str(b))
plt.show()
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Uniforme entre 0 y "+str(b))
plt.show()
#Tipo de Arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Uniforme son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Uniforme son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Uniforme son u= 127.5 var= 5418.75
# Los valores estimados en nuestro experimento de la media y varianza para la Uniforme son u_est= 127.73372178414431 var_est= 5413.755788853737
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.0018331120325043746 % de la media 0.0009216537294142185 % de la varianza

# %%
#T de Student con paramero K 
from scipy.stats import t
K=8.0
mean, var, skew, kurt = t.stats(moments='mvsk',df=K)
u=mean
std=var
r = t.rvs (df=K, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t con media="+str(u)+" y var="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos t ordenados con media="+str(u)+" y var="+str(std))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos t con u="+str(u)+ " y var= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 0.0 var= 1.3333333333333333
# Los valores estimados en nuestro experimento de la media y varianza son u_est= -0.0006275570079524186 var_est= 1.3231397930027335

# %%
# Exponencial con Lamnda L
L=0.3
from scipy.stats import expon
mean, var = scipy.stats.expon.stats(moments='mv',loc=0,scale=L)
r = scipy.stats.expon.rvs (loc=0,scale=L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Exponencial con L= "+str(L))
plt.show()
#Ordenado
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Exponencial ordenados con L= "+str(L))
plt.show()
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Exponencial con L= "+str(L))
plt.show()
#Tipo de Arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Exponencial son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Exponencial son u= 0.3 var= 0.09
# Los valores estimados en nuestro experimento de la media y varianza para la Exponencial son u_est= 0.30079635573985747 var_est= 0.09089099576241666
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.002654519132858265 % de la media 0.009899952915740702 % de la varianza

# %%
#Chi cuadrada con K grados de libertad
K=3.0
from scipy.stats import chi2
mean, var = scipy.stats.chi2.stats(df=K, moments='mv',loc=0,scale=1)
r = chi2.rvs (df=K, loc=0,scale=1, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Chi Cuadrada con K= "+str(K))
plt.show()
#Ordenado
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Chi Cuadrada ordenados con K= "+str(K))
plt.show()
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Chi Cuadrada con K= "+str(K))
plt.show()
#Tipo de Arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Chi Cuadrada son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Chi Cuadrada son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Chi Cuadrada son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza para la Chi Cuadrada son u_est= 3.0085742764673555 var_est= 5.980995446574694
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.002858092155785178 % de la media 0.003167425570884378 % de la varianza

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
from scipy.stats import gamma
mean, var = scipy.stats.gamma.stats(a=k, moments='mv',loc=0,scale=t)
r = gamma.rvs (a=k, loc=0,scale=t, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Gamma con k= "+str(k)+" y theta "+str(t))
plt.show()
#Ordenado
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Gamma ordenados con k= "+str(K)+" y theta "+str(t))
plt.show()
#Histograma
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Gamma con k= "+str(k)+" y theta "+str(t))
plt.show()
#Tipo de Arreglo
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Gamma son u_est=" ,avg,"var_est=",varest)
#Porcentaje de Error
errorm= abs((mean-avg)/mean)
errorv= abs((var-varest)/var)
print("El porcentaje error entre los valores teóricos y los obtenidos son los siguientes: ", errorm, "% de la media", errorv, "% de la varianza")
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Gamma son u= 1.0922 var= 0.469646
# Los valores estimados en nuestro experimento de la media y varianza para la Gamma son u_est= 1.092824151531942 var_est= 0.4712913292795127
# El porcentaje error entre los valores teóricos y los obtenidos son los siguientes:  0.0005714626734497721 % de la media 0.003503339280037985 % de la varianza
